# %% [markdown]
# # **Proyecto #8: Clustering y visualización de curvas de luz de estrellas periódicas**
# ## **EL4106 - Inteligencia Computacional - Primavera 2022**
# ### **Parte 1 : Curvas de Luz y extracción de características**
# ##### **Profesor:** Pablo Estevez
# ##### **Auxiliar:** Juan Uturria
# ##### **Ayudante:** Rafael de la Sotta Vargas
# ##### **Estudiantes:** Macarena Ríos - Melanie Peña

# %% [markdown]
# ## 1) Librerías a importar para la experiencia

# %%
import numpy as np
import pandas as pd
import random
# %matplotlib inline
from google.colab import files
from google.colab import drive
drive.mount('/content/drive') #toda la data se fue cargada al drive personal para poder ejecutar
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Instalación de la libreria TurboFats para la extracción de características
# !python -m pip install Cython
# !python -m pip install -e git+https://git@github.com/alercebroker/turbo-fats#egg=turbofats
# !python -m pip install -e git+https://git@github.com/alercebroker/mhps#egg=mhps
# !python -m pip install -e git+https://git@github.com/alercebroker/P4J#egg=P4J
# !python -m pip install pyarrow 
# !python -m pip install -e git+https://git@github.com/alercebroker/lc_classifier#egg=lc_classifier
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Cython in /usr/local/lib/python3.7/dist-packages (0.29.32)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining turbofats from git+https://****@github.com/alercebroker/turbo-fats#egg=turbofats
#   Cloning https://****@github.com/alercebroker/turbo-fats to ./src/turbofats
#   Running command git clone -q 'https://****@github.com/alercebroker/turbo-fats' /content/src/turbofats
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from turbofats) (1.21.6)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from turbofats) (0.56.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from turbofats) (1.7.3)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.7/dist-packages (from turbofats) (0.12.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->turbofats) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->turbofats) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba->turbofats) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->turbofats) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->turbofats) (4.1.1)
# Requirement already satisfied: pandas>=0.21 in /usr/local/lib/python3.7/dist-packages (from statsmodels->turbofats) (1.3.5)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from statsmodels->turbofats) (0.5.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21->statsmodels->turbofats) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21->statsmodels->turbofats) (2022.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5->statsmodels->turbofats) (1.15.0)
# Installing collected packages: turbofats
#   Running setup.py develop for turbofats
# Successfully installed turbofats-2.0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining mhps from git+https://****@github.com/alercebroker/mhps#egg=mhps
#   Cloning https://****@github.com/alercebroker/mhps to ./src/mhps
#   Running command git clone -q 'https://****@github.com/alercebroker/mhps' /content/src/mhps
# Requirement already satisfied: numpy>=1.17.4 in /usr/local/lib/python3.7/dist-packages (from mhps) (1.21.6)
# Requirement already satisfied: Cython>=0.29.12 in /usr/local/lib/python3.7/dist-packages (from mhps) (0.29.32)
# Installing collected packages: mhps
#   Running setup.py develop for mhps
# Successfully installed mhps-0.1.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining P4J from git+https://****@github.com/alercebroker/P4J#egg=P4J
#   Cloning https://****@github.com/alercebroker/P4J to ./src/p4j
#   Running command git clone -q 'https://****@github.com/alercebroker/P4J' /content/src/p4j
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from P4J) (1.21.6)
# Installing collected packages: P4J
#   Running setup.py develop for P4J
# Successfully installed P4J-1.1.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.7/dist-packages (6.0.1)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.7/dist-packages (from pyarrow) (1.21.6)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining lc_classifier from git+https://****@github.com/alercebroker/lc_classifier#egg=lc_classifier
#   Cloning https://****@github.com/alercebroker/lc_classifier to ./src/lc-classifier
#   Running command git clone -q 'https://****@github.com/alercebroker/lc_classifier' /content/src/lc-classifier
# Requirement already satisfied: astropy>=4.0 in /usr/local/lib/python3.7/dist-packages (from lc_classifier) (4.3.1)
# Requirement already satisfied: click>=7.1 in /usr/local/lib/python3.7/dist-packages (from lc_classifier) (7.1.2)
# Requirement already satisfied: Cython>=0.29 in /usr/local/lib/python3.7/dist-packages (from lc_classifier) (0.29.32)
# Collecting GPy>=1.9
#   Downloading GPy-1.10.0.tar.gz (959 kB)
#      |████████████████████████████████| 959 kB 18.1 MB/s
# Requirement already satisfied: Jinja2>=2.11 in /usr/local/lib/python3.7/dist-packages (from lc_classifier) (2.11.3)
# Requirement already satisfied: imbalanced-learn>=0.7 in /usr/local/lib/python3.7/dist-packages (from lc_classifier) (0.8.1)
# Collecting matplotlib>=3.3
#   Downloading matplotlib-3.5.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 54.1 MB/s
# Requirement already satisfied: numba>=0.51 in /usr/local/lib/python3.7/dist-packages (from lc_classifier) (0.56.3)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.7/dist-packages (from lc_classifier) (1.21.6)
# Collecting requests>=2.24
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 54 kB/s
# Requirement already satisfied: scipy>=1.4 in /usr/local/lib/python3.7/dist-packages (from lc_classifier) (1.7.3)
# Requirement already satisfied: setuptools>=49.6 in /usr/local/lib/python3.7/dist-packages (from lc_classifier) (57.4.0)
# Requirement already satisfied: scikit-learn>=0.23 in /usr/local/lib/python3.7/dist-packages (from lc_classifier) (1.0.2)
# Requirement already satisfied: tqdm>=4.48 in /usr/local/lib/python3.7/dist-packages (from lc_classifier) (4.64.1)
# Requirement already satisfied: tensorflow>=2.3 in /usr/local/lib/python3.7/dist-packages (from lc_classifier) (2.9.2)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.7/dist-packages (from lc_classifier) (1.3.5)
# Collecting wget>=3.2
#   Downloading wget-3.2.zip (10 kB)
# Collecting celerite2>=0.1
#   Downloading celerite2-0.2.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (922 kB)
#      |████████████████████████████████| 922 kB 53.7 MB/s
# Collecting pickle5
#   Downloading pickle5-0.0.12-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (256 kB)
#      |████████████████████████████████| 256 kB 75.1 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from astropy>=4.0->lc_classifier) (4.13.0)
# Requirement already satisfied: pyerfa>=1.7.3 in /usr/local/lib/python3.7/dist-packages (from astropy>=4.0->lc_classifier) (2.0.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from GPy>=1.9->lc_classifier) (1.15.0)
# Collecting paramz>=0.9.0
#   Downloading paramz-0.9.5.tar.gz (71 kB)
#      |████████████████████████████████| 71 kB 8.6 MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn>=0.7->lc_classifier) (1.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=2.11->lc_classifier) (2.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->lc_classifier) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->lc_classifier) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->lc_classifier) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->lc_classifier) (7.1.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      |████████████████████████████████| 965 kB 47.3 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->lc_classifier) (21.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->lc_classifier) (0.11.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib>=3.3->lc_classifier) (4.1.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.51->lc_classifier) (0.39.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1->lc_classifier) (2022.5)
# Requirement already satisfied: decorator>=4.0.10 in /usr/local/lib/python3.7/dist-packages (from paramz>=0.9.0->GPy>=1.9->lc_classifier) (4.4.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.24->lc_classifier) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.24->lc_classifier) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.24->lc_classifier) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.24->lc_classifier) (2022.9.24)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.23->lc_classifier) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3->lc_classifier) (1.14.1)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3->lc_classifier) (1.12)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3->lc_classifier) (3.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3->lc_classifier) (3.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3->lc_classifier) (1.3.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3->lc_classifier) (2.9.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3->lc_classifier) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3->lc_classifier) (2.0.1)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3->lc_classifier) (2.9.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3->lc_classifier) (0.27.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3->lc_classifier) (2.9.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3->lc_classifier) (0.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3->lc_classifier) (1.50.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3->lc_classifier) (3.17.3)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3->lc_classifier) (14.0.6)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3->lc_classifier) (1.1.2)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3->lc_classifier) (1.6.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow>=2.3->lc_classifier) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow>=2.3->lc_classifier) (1.5.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.3->lc_classifier) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.3->lc_classifier) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.3->lc_classifier) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.3->lc_classifier) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.3->lc_classifier) (1.35.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.3->lc_classifier) (3.4.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.3->lc_classifier) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.3->lc_classifier) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.3->lc_classifier) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=2.3->lc_classifier) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->astropy>=4.0->lc_classifier) (3.9.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.3->lc_classifier) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=2.3->lc_classifier) (3.2.2)
# Building wheels for collected packages: GPy, paramz, wget
#   Building wheel for GPy (setup.py) ... done
#   Created wheel for GPy: filename=GPy-1.10.0-cp37-cp37m-linux_x86_64.whl size=2565143 sha256=27fcf360361ab1c7aa1b82ef32119027c589fcdc1932cbabe2ab9d14b5ed5c5a
#   Stored in directory: /root/.cache/pip/wheels/f7/18/28/dd1ce0192a81b71a3b086fd952511d088b21e8359ea496860a
#   Building wheel for paramz (setup.py) ... done
#   Created wheel for paramz: filename=paramz-0.9.5-py3-none-any.whl size=102566 sha256=9807cf040e7d7dfd946dc26fb5f08499dcf5aeacc7eee08238e88900f22cf20b
#   Stored in directory: /root/.cache/pip/wheels/c8/95/f5/ce28482da28162e6028c4b3a32c41d147395825b3cd62bc810
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=89f23fa2083f327d16de1f1ed84f442ea2930f03f697c0a969f662d819682867
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built GPy paramz wget
# Installing collected packages: requests, paramz, fonttools, wget, pickle5, matplotlib, GPy, celerite2, lc-classifier
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
#   Running setup.py develop for lc-classifier
# Successfully installed GPy-1.10.0 celerite2-0.2.1 fonttools-4.38.0 lc-classifier-2.0.1 matplotlib-3.5.3 paramz-0.9.5 pickle5-0.0.12 requests-2.28.1 wget-3.2

# %% [markdown]
# Una vez ejecutado el bloque anterior, reiniciar el entorno de ejecución para poder importar las siguientes funciones relevantes para el desarrollo del proyecto.

# %%
#características de la libreria a utilizar 
from lc_classifier.features import MHPSExtractor, PeriodExtractor, GPDRWExtractor
from lc_classifier.features import FoldedKimExtractor
from lc_classifier.features import HarmonicsExtractor, IQRExtractor
from lc_classifier.features import PowerRateExtractor
from lc_classifier.features import TurboFatsFeatureExtractor
from lc_classifier.features import FeatureExtractorComposer

# %% [markdown]
# ## 2) Cargar la data a utilizar

# %%
labels =  pd.read_csv("/content/drive/MyDrive/labels_set.csv")
alerts =  pd.read_csv("/content/drive/MyDrive/alert_detections_V2.csv",iterator=True,chunksize=100000) #debido a que la data de alerts es demasiado grande, se debe recorrer
                                                                                                       #en pedazos

# %%
labels #visualización de todo el inventario de estrellas que existen
# Out:
#                  oid classALeRCE          ra        dec            source  \
# 0       ZTF19aapcxhy         AGN  154.202129  18.723076            Oh2015
# 1       ZTF18abtmwvo         AGN   46.074050   0.474212            Oh2015
# 2       ZTF18acvgdfy         AGN  134.407409   5.472596            Oh2015
# 3       ZTF19aabvjsi         AGN  132.353298  14.067266            Oh2015
# 4       ZTF18aadyxlg         AGN  125.577004  33.091120            Oh2015
# ...              ...         ...         ...        ...               ...
# 123491  ZTF17aaanrhv         YSO  100.188180   9.478992  Simbad_variables
# 123492  ZTF18aabgmld         YSO  100.248642   9.478838  Simbad_variables
# 123493  ZTF17aaarpje         YSO   84.062814  -6.293581  Simbad_variables
# 123494  ZTF18actawih         YSO   83.880279  -5.669713  Simbad_variables
# 123495  ZTF18acrvapr         YSO   82.613258  -1.242000  Simbad_variables
#
#                       id_source
# 0         5.877420127343739e+17
# 1         5.880155098263717e+17
# 2         5.877327033915148e+17
# 3         5.877420137987442e+17
# 4         5.880133827239608e+17
# ...                         ...
# 123491            EM* LkHA  364
# 123492                V* LV Mon
# 123493                V* BB Ori
# 123494             V* V1558 Ori
# 123495  2MASS J05302717-0114311
#
# [123496 rows x 6 columns]

# %%
labels.groupby(by="classALeRCE").count()["oid"].to_dict() #desbalance de clases, 15 clases dentro del inventario
# Out:
# {'AGN': 4667,
#  'Blazar': 1267,
#  'CEP': 618,
#  'CV/Nova': 871,
#  'DSCT': 732,
#  'E': 37901,
#  'LPV': 14076,
#  'Periodic-Other': 1256,
#  'QSO': 26168,
#  'RRL': 32482,
#  'SLSN': 24,
#  'SNII': 328,
#  'SNIa': 1272,
#  'SNIbc': 94,
#  'YSO': 1740}

# %% [markdown]
# ## 3) Obtención de las estrellas periódicas

# %%
#Debido a que el proyecto corresponde especificamente a estrellas periódicas, procedemos eliminando todas las estrellas que no correspondan de la data de labels
#creando una función auxiliar que recorra la data de labels y dropee aquellas estrellas no necesarias
#Clases de estrellas periódicas : Long Period Variable (LPV), Cepheid (CEP), RR Lyrae (RRL), δ Scuti (DSCT), Eclipsing Binary (E) y Periodic-Other
def periodic(data):
  nonperiodic = ['AGN', 'Blazar', 'CV/Nova', 'QSO', 'SLSN', 'SNII','SNIa','SNIbc','YSO'] #estrellas no periodicas
  for i in range(len(nonperiodic)):
    index1 = data[data["classALeRCE"] == nonperiodic[i]].index 
    data.drop(index1, inplace=True)
  return labels

# %%
periodic(labels)
# Out:
#                  oid     classALeRCE          ra        dec     source  \
# 6805    ZTF18abwwdsc             CEP  326.755845  -8.060673  CRTSnorth
# 6806    ZTF18aaakigd             CEP   65.440016  34.069809  CRTSnorth
# 6807    ZTF18abwwdxw             CEP  324.865973 -17.296145  CRTSnorth
# 6808    ZTF19aaocniv             CEP  248.580619 -16.015739  CRTSnorth
# 6809    ZTF17aacemqz             CEP  117.977671  27.561363  CRTSnorth
# ...              ...             ...         ...        ...        ...
# 120033  ZTF18abwwdwe  Periodic-Other  330.079004 -10.046703  CRTSnorth
# 120034  ZTF19aceilmk  Periodic-Other  312.373578   1.105685  CRTSnorth
# 120035  ZTF18abtyrpc  Periodic-Other  351.078025  31.870857  CRTSnorth
# 120036  ZTF18actuvrp  Periodic-Other  203.937280  -8.807032  CRTSnorth
# 120037  ZTF18acrygmq  Periodic-Other  200.572177  -3.022731  CRTSnorth
#
#               id_source
# 6805    1007116010622.0
# 6806    1135020009815.0
# 6807    1018112055304.0
# 6808    1015086048064.0
# 6809    1126038065052.0
# ...                 ...
# 120033  1009117031057.0
# 120034  1101112046278.0
# 120035  1132108024048.0
# 120036  1009072054924.0
# 120037  1004072058208.0
#
# [87065 rows x 6 columns]

# %%
labels.groupby(by="classALeRCE").count()["oid"].to_dict()
# Out:
# {'CEP': 618,
#  'DSCT': 732,
#  'E': 37901,
#  'LPV': 14076,
#  'Periodic-Other': 1256,
#  'RRL': 32482}

# %%
#este bloque sirve para guardar la data de las estrellas periodicas, descomentar en caso de que se desee obtener el csv correspondiente
#labels.to_csv('periodicas.csv') 
#files.download('periodicas.csv')

# %% [markdown]
# ## 4) Sampling de estrellas y Curvas de Luz

# %% [markdown]
# Como se puede verificar en la sección 3) es evidente notar para obtener un balanceo entre las clases hay que tener en consideración que la cantidad de estrellas que pertenecen a la clase CEP son 618. Por ende, no se le puede pedir una cantidad mayor a esta clase. Por esta razón se van a utilizar un sample de 600 estrellas para cada una de las clases, sin embargo, para la clase CEP se van a utilizar las 618 estrellas en su totalidad.
#
# Para poder obtener un sample de cada una de las clases estrellas se decidió como primer paso obtener la data POR SEPARADO de cada una de las clases, con esto se quiere decir que se creo un dataset para la clase CEP, uno para la clase RRL, y lo mismo para las otras clases restantes. Para esto se utilizo la siguiente función auxiliar:

# %%
def single_class(data):
  nointerest = ['CEP','RRL','DSCT','E','Periodic-Other'] #obtener data LPV
  #nointerest = ['LPV','RRL','DSCT','E','Periodic-Other'] #Obtener data CEP
  #nointerest = ['LPV','CEP','DSCT','E','Periodic-Other'] #obtener data RRL
  #nointerest = ['LPV','CEP','RRL','E','Periodic-Other'] #obtener data DSCT
  #nointerest = ['LPV','CEP','RRL','DSCT','Periodic-Other'] #obtener data E
  #nointerest = ['LPV','CEP','RRL','DSCT','E'] #obtener data Periodic-Other
  for i in range(len(nointerest)):
    index2 = data[data["classALeRCE"] == nointerest[i]].index 
    data.drop(index2, inplace=True)
  return data

# %%
single_class(labels)
# Out:
#                 oid classALeRCE          ra        dec     source  \
# 46056  ZTF18abucchs         LPV  315.078308  -6.115294  CRTSnorth
# 46057  ZTF18aabhkdy         LPV  106.498180  52.477287  CRTSnorth
# 46058  ZTF18aagvrdt         LPV  247.282715  34.229506  CRTSnorth
# 46059  ZTF18aaiylnl         LPV  251.918113  56.967817  CRTSnorth
# 46060  ZTF18aabebwy         LPV  187.742089  12.308543  CRTSnorth
# ...             ...         ...         ...        ...        ...
# 60127  ZTF18aaxymzx         LPV  295.919157  22.724404  GAIADR2VS
# 60128  ZTF18abikbvc         LPV  286.720222  24.733440  GAIADR2VS
# 60129  ZTF19aamtoyb         LPV   99.257590 -15.567786  GAIADR2VS
# 60130  ZTF18abnubuy         LPV  292.053754  38.418277  GAIADR2VS
# 60131  ZTF18abgqxlw         LPV  280.809676  12.634607  GAIADR2VS
#
#                     id_source
# 46056         1007112078870.0
# 46057         1152024060987.0
# 46058         1135073011544.0
# 46059         1157050015163.0
# 46060         1112066024303.0
# ...                       ...
# 60127  2.0199127469765652e+18
# 60128   4.533629080944307e+18
# 60129  2.9501070744892713e+18
# 60130  2.0526959231045647e+18
# 60131   4.505379156900003e+18
#
# [14076 rows x 6 columns]

# %% [markdown]
# Como se puede verificar se obtuvo de manera exitosa la data total correspondiente a la data de la clase LPV. Para poder obtener la data de cada una de las clases se debe ejecutar los bloques de cargar la data labels (sección 2), la obtención de la data para las estrellas periódicas (sección 3) y finalmente descomentar la línea de código dentro de la función single_class correspondiente para obtener cada una de las datas deseadas. Se procede a guardar cada una de estas datas y se guardan en las siguientes variables.

# %%
LPV = pd.read_csv("/content/drive/MyDrive/Proyecto8/DataFrames /LPV.csv")
CEP = pd.read_csv("/content/drive/MyDrive/Proyecto8/DataFrames /CEP.csv")
RRL = pd.read_csv("/content/drive/MyDrive/Proyecto8/DataFrames /RRL.csv")
DSCT = pd.read_csv("/content/drive/MyDrive/Proyecto8/DataFrames /DSCT.csv")
E = pd.read_csv("/content/drive/MyDrive/Proyecto8/DataFrames /E.csv")
PeriodicOther = pd.read_csv("/content/drive/MyDrive/Proyecto8/DataFrames /PeriodicOther.csv")

# %% [markdown]
# Para los siguientes pasos a seguir, se va a utilizar solo una de clases para la demostración de lo que se debe utilizar con todas las siguientes, de todas formas se entregan las líneas de código comentadas para realizar el proceso con todas las clases. La clase a utilizar como ejemplo corresponde a la clase LPV.

# %%
#Como primer paso, se deben obtener todos los id de las estrellas de cada una de las clases

oids = LPV["oid"]
#oids = RRL["oid"]
#oids = DSCT["oid"]
#oids = E["oid"]
#oids = PeriodicOther["oid"]
#no existe este sección para la clase CEP, debido a que no se realiza un sampling para esta clase, se utilizan
#las 618 estrellas en su totalidad


#Sampling de 600 estrellas para cada clase, estos samples cambian cada vez que se ejecuta debido a que se
#utiliza la librería random
oid_array = oids.to_numpy()

def tolist(array):
  list=[]
  for i in range(len(array)): list.append(array[i])
  return list

oid_list = tolist(oid_array) 
oid_sample = random.sample(oid_list, 600)
oid_sample
# Out:
# ['ZTF19aargivj',
#  'ZTF18abeojzu',
#  'ZTF18ablqphs',
#  'ZTF18abdihyu',
#  'ZTF18abecfha',
#  'ZTF18abmozjd',
#  'ZTF19aazrjzs',
#  'ZTF18abegcjn',
#  'ZTF18abusfrv',
#  'ZTF18aahdrhl',
#  'ZTF18aazvdop',
#  'ZTF18abmagoo',
#  'ZTF18abjwmnk',
#  'ZTF18abeymgq',
#  'ZTF18aazvxtd',
#  'ZTF18abmewoh',
#  'ZTF18abfxgjy',
#  'ZTF18ablqldx',
#  'ZTF18abloqju',
#  'ZTF18abeelyq',
#  'ZTF18abdhxbc',
#  'ZTF18abfyvpj',
#  'ZTF17aaatizh',
#  'ZTF18abcwyuj',
#  'ZTF18abnouyz',
#  'ZTF18aazmpvx',
#  'ZTF17aaadzrt',
#  'ZTF18ablpvwt',
#  'ZTF18aavyvgn',
#  'ZTF18abcjupf',
#  'ZTF18abgjkab',
#  'ZTF18acakuxw',
#  'ZTF18abnbnxt',
#  'ZTF18abizqrv',
#  'ZTF17aaapvrg',
#  'ZTF18aazfeah',
#  'ZTF18absmddt',
#  'ZTF18aasnizu',
#  'ZTF18aavfequ',
#  'ZTF18aawsrvo',
#  'ZTF18aayfbbb',
#  'ZTF18abdlbtu',
#  'ZTF18aayeigr',
#  'ZTF18abmvwml',
#  'ZTF18abnjyxg',
#  'ZTF18aaxahvh',
#  'ZTF18abmnyky',
#  'ZTF18abcurws',
#  'ZTF19aaxtwjs',
#  'ZTF19aaeslxf',
#  'ZTF17aaawgkz',
#  'ZTF18abslvkv',
#  'ZTF18abgfmix',
#  'ZTF18abcbspm',
#  'ZTF18ablvhgn',
#  'ZTF18abvcjao',
#  'ZTF18abgzyiw',
#  'ZTF18abncaon',
#  'ZTF18aasnnjn',
#  'ZTF18abdfqyk',
#  'ZTF19aazrlmr',
#  'ZTF19aakvuue',
#  'ZTF19achthna',
#  'ZTF18abbemaw',
#  'ZTF18abrzhie',
#  'ZTF17aadiwon',
#  'ZTF18aaveemr',
#  'ZTF17aaafidr',
#  'ZTF18abkoclg',
#  'ZTF18aaxjdje',
#  'ZTF17aaawcxu',
#  'ZTF18abaegcb',
#  'ZTF18abnopxx',
#  'ZTF18abjpdqa',
#  'ZTF18acbuynw',
#  'ZTF18abjujbr',
#  'ZTF18aazlupi',
#  'ZTF18abcpuyb',
#  'ZTF18abapheu',
#  'ZTF18ablqzhr',
#  'ZTF18abmrxnc',
#  'ZTF18abkodyn',
#  'ZTF18abvozji',
#  'ZTF18aanacxx',
#  'ZTF19aafnpjp',
#  'ZTF18abdkebl',
#  'ZTF18aaxywju',
#  'ZTF18aabfyrs',
#  'ZTF18abjqayd',
#  'ZTF18aaxjjot',
#  'ZTF19acbuzqn',
#  'ZTF18abijbrx',
#  'ZTF18ablhulf',
#  'ZTF18abgrycu',
#  'ZTF18abucyss',
#  'ZTF18abrrjrh',
#  'ZTF18abmtezr',
#  'ZTF18abmrfpr',
#  'ZTF18aapmpsu',
#  'ZTF19aatiegk',
#  'ZTF18abscszd',
#  'ZTF18aceodik',
#  'ZTF18abiykmr',
#  'ZTF18ablvqdr',
#  'ZTF18abdzpqy',
#  'ZTF17aaawgds',
#  'ZTF18aaveemw',
#  'ZTF18aaxdoeg',
#  'ZTF18aaynsxm',
#  'ZTF18aberbac',
#  'ZTF18abjhcdr',
#  'ZTF18aayoytx',
#  'ZTF18adayhnj',
#  'ZTF19aazhlmh',
#  'ZTF18abecmpg',
#  'ZTF18abaqxsv',
#  'ZTF18abjqmrh',
#  'ZTF18abfxftb',
#  'ZTF18abtviuv',
#  'ZTF19aawchcc',
#  'ZTF18aaynsne',
#  'ZTF18abgshgt',
#  'ZTF18abjlqro',
#  'ZTF18abigvbg',
#  'ZTF18aazvrmr',
#  'ZTF18abaqyie',
#  'ZTF18abmdumi',
#  'ZTF18acbcjdr',
#  'ZTF18aavzkfk',
#  'ZTF18abcdwwe',
#  'ZTF19aazguhj',
#  'ZTF19aaggmbl',
#  'ZTF18aaxyudr',
#  'ZTF18abnjznm',
#  'ZTF18abbnjhc',
#  'ZTF18aaxunev',
#  'ZTF18aazwcgf',
#  'ZTF18abrrvor',
#  'ZTF18aawloox',
#  'ZTF18abrvkym',
#  'ZTF18aazvfks',
#  'ZTF19aasgotn',
#  'ZTF18abncfuu',
#  'ZTF18abcrehc',
#  'ZTF18abmotvn',
#  'ZTF18abjibuy',
#  'ZTF18ablqnhv',
#  'ZTF18abcnokv',
#  'ZTF19aasgotm',
#  'ZTF18aaqzdlu',
#  'ZTF18aayvccw',
#  'ZTF18abobikz',
#  'ZTF18abgruej',
#  'ZTF19aasjgkm',
#  'ZTF18ablpuer',
#  'ZTF18ablpouq',
#  'ZTF18aawcesj',
#  'ZTF18abajkmu',
#  'ZTF18abpfgyi',
#  'ZTF18abyohjt',
#  'ZTF18aaxdpdc',
#  'ZTF18abijnme',
#  'ZTF18abtuzwy',
#  'ZTF18abmxzbo',
#  'ZTF18abecvib',
#  'ZTF18abygcjc',
#  'ZTF18aaxdaah',
#  'ZTF18abegbij',
#  'ZTF18aawumaq',
#  'ZTF18abbmmue',
#  'ZTF18abgsjnt',
#  'ZTF18aayvgaf',
#  'ZTF18aaveqih',
#  'ZTF18aaabjkh',
#  'ZTF18aaaauat',
#  'ZTF18abebeya',
#  'ZTF19aayhryp',
#  'ZTF18abhxxar',
#  'ZTF18abjaaab',
#  'ZTF18abfkxat',
#  'ZTF18abijtqt',
#  'ZTF18aaxangy',
#  'ZTF18aayednf',
#  'ZTF19aaocfhv',
#  'ZTF18abnvunz',
#  'ZTF18abmehcs',
#  'ZTF18aayuszt',
#  'ZTF18acwwdfw',
#  'ZTF18aaxujpt',
#  'ZTF18abjfhcr',
#  'ZTF18abdlbzr',
#  'ZTF18aaxyuvh',
#  'ZTF19aazrkxp',
#  'ZTF18aavzkuj',
#  'ZTF18abyitqu',
#  'ZTF18aayethh',
#  'ZTF18aaxjjoh',
#  'ZTF18abjueha',
#  'ZTF19aaoduvc',
#  'ZTF18abdlxcr',
#  'ZTF18abpfgtx',
#  'ZTF18aasnpsl',
#  'ZTF17aaajmcg',
#  'ZTF18abfrpyu',
#  'ZTF18aavqkrh',
#  'ZTF19aaedqwo',
#  'ZTF18abikphx',
#  'ZTF18abkixvq',
#  'ZTF18abfitme',
#  'ZTF18abfscmj',
#  'ZTF18aayelqk',
#  'ZTF18abncctw',
#  'ZTF18ablrxkp',
#  'ZTF19abaocpa',
#  'ZTF18abpfjie',
#  'ZTF18abvqbiu',
#  'ZTF18abutalw',
#  'ZTF18abcmtwi',
#  'ZTF18abdlhnv',
#  'ZTF18aaxalkw',
#  'ZTF19aaxrnvo',
#  'ZTF19acuowue',
#  'ZTF18abndwlo',
#  'ZTF18abnchrm',
#  'ZTF18abikbxf',
#  'ZTF18aayuxsw',
#  'ZTF18abdkuvd',
#  'ZTF18abdiihq',
#  'ZTF18acszjfq',
#  'ZTF18abcpjzl',
#  'ZTF18absambs',
#  'ZTF19abagadb',
#  'ZTF18abpfeyr',
#  'ZTF18abmjhuw',
#  'ZTF18abpffcp',
#  'ZTF18acaurdb',
#  'ZTF18ablvyzy',
#  'ZTF19aadoqwk',
#  'ZTF18aauenas',
#  'ZTF18ablsdpg',
#  'ZTF19aapqkuh',
#  'ZTF18abaymbp',
#  'ZTF18abezazm',
#  'ZTF18abobvwn',
#  'ZTF18abebwga',
#  'ZTF18aavegme',
#  'ZTF18aborumk',
#  'ZTF18aabfhdx',
#  'ZTF18abmortg',
#  'ZTF18abdeuds',
#  'ZTF18abbugac',
#  'ZTF18abdjqqq',
#  'ZTF17aaaheln',
#  'ZTF18abpfpal',
#  'ZTF17aaaecfy',
#  'ZTF18abpfett',
#  'ZTF18abezirj',
#  'ZTF18aaxlufw',
#  'ZTF19aakvuoe',
#  'ZTF19aaxtyoo',
#  'ZTF18acxhkzz',
#  'ZTF19aaodveg',
#  'ZTF18aawvbdk',
#  'ZTF19abagizm',
#  'ZTF18abokqog',
#  'ZTF19aaeqmae',
#  'ZTF18aberdsm',
#  'ZTF19aapqozb',
#  'ZTF19aapqimh',
#  'ZTF18abypodv',
#  'ZTF18abdkhke',
#  'ZTF18abtowjq',
#  'ZTF18abebnae',
#  'ZTF18abktvmi',
#  'ZTF18abcqyoi',
#  'ZTF18aayorkw',
#  'ZTF19aazrlnd',
#  'ZTF18aaxytuw',
#  'ZTF18abmdjmt',
#  'ZTF19abamxyl',
#  'ZTF18abcvdze',
#  'ZTF18abtvhxv',
#  'ZTF18abacgfe',
#  'ZTF18aavynte',
#  'ZTF18abnjzki',
#  'ZTF18absuola',
#  'ZTF18aavzmbp',
#  'ZTF18aceumae',
#  'ZTF18abpptpa',
#  'ZTF18abvepzt',
#  'ZTF18aaxlotw',
#  'ZTF18aaueaah',
#  'ZTF18aavzlcr',
#  'ZTF18aazeywq',
#  'ZTF18aczedyq',
#  'ZTF18aabfgfr',
#  'ZTF18abnuelr',
#  'ZTF18aakygem',
#  'ZTF17aaaeblo',
#  'ZTF18aamplcd',
#  'ZTF18abwfmfd',
#  'ZTF18aabfhmg',
#  'ZTF18abpsbvj',
#  'ZTF19aadorsa',
#  'ZTF18abcnlfe',
#  'ZTF18abnuiin',
#  'ZTF18abcjmwa',
#  'ZTF18absqzkd',
#  'ZTF18abimnxe',
#  'ZTF18abnjyqx',
#  'ZTF18ablrvvf',
#  'ZTF18abdlake',
#  'ZTF19aawzasm',
#  'ZTF18aaoanbq',
#  'ZTF18abnoynn',
#  'ZTF17aaadybz',
#  'ZTF18aayejxy',
#  'ZTF18abdyezk',
#  'ZTF18abmsrqa',
#  'ZTF18aaxjdti',
#  'ZTF18aaveezj',
#  'ZTF18aaxjcxt',
#  'ZTF18abmapsj',
#  'ZTF19aayyzxp',
#  'ZTF18abgviqo',
#  'ZTF18abjtbsg',
#  'ZTF18aayedkk',
#  'ZTF19aamqtlb',
#  'ZTF18acmihyc',
#  'ZTF18abchljl',
#  'ZTF18acwfruh',
#  'ZTF18abmjhul',
#  'ZTF19aafntuy',
#  'ZTF18abcpdwc',
#  'ZTF19abprmyi',
#  'ZTF18abbcynv',
#  'ZTF18abfituu',
#  'ZTF18aaywgnz',
#  'ZTF18abmqtyc',
#  'ZTF18ablqlhb',
#  'ZTF18abfroxp',
#  'ZTF18abdjvrg',
#  'ZTF18abthuon',
#  'ZTF18aayhinm',
#  'ZTF17aaafkxc',
#  'ZTF18aavefeb',
#  'ZTF18abrrywl',
#  'ZTF18aaxplqy',
#  'ZTF19aawqfti',
#  'ZTF18aazwegy',
#  'ZTF18abncbvj',
#  'ZTF18abmelwy',
#  'ZTF19abumoef',
#  'ZTF18ablqlkr',
#  'ZTF18aabgkpz',
#  'ZTF18abgsgso',
#  'ZTF18abmrfxr',
#  'ZTF18abjhele',
#  'ZTF18accxoqb',
#  'ZTF17aaaeajo',
#  'ZTF18aazwlph',
#  'ZTF19aadoren',
#  'ZTF18abfivmz',
#  'ZTF19aadhdvz',
#  'ZTF18aaxcyxf',
#  'ZTF19aarguwj',
#  'ZTF18abmexqk',
#  'ZTF18aaxpowz',
#  'ZTF18ablxcyv',
#  'ZTF18abokxel',
#  'ZTF18abchoso',
#  'ZTF18aayecnl',
#  'ZTF18acrwlus',
#  'ZTF18aawcfnq',
#  'ZTF18aaaatbf',
#  'ZTF18abqawar',
#  'ZTF18aazvkbv',
#  'ZTF18aabkikb',
#  'ZTF18aaxanmc',
#  'ZTF17aaborci',
#  'ZTF18abtpala',
#  'ZTF18abrnhqk',
#  'ZTF18abnvuoi',
#  'ZTF18abcyvkm',
#  'ZTF19aakqsqu',
#  'ZTF18aazayzl',
#  'ZTF18abouuok',
#  'ZTF18aaxdcxy',
#  'ZTF18absijng',
#  'ZTF18abgramq',
#  'ZTF18abmfwki',
#  'ZTF18aauesun',
#  'ZTF18abmeytp',
#  'ZTF19aazrkqg',
#  'ZTF18abchsxz',
#  'ZTF18abebodz',
#  'ZTF17aabqicv',
#  'ZTF18acrvacy',
#  'ZTF18abcmsvy',
#  'ZTF18abnorou',
#  'ZTF18aboqctc',
#  'ZTF18aasnmpy',
#  'ZTF18aaxyuft',
#  'ZTF18achpcxy',
#  'ZTF17aabvfyo',
#  'ZTF17aabpioh',
#  'ZTF19aargvqt',
#  'ZTF18abgxoqn',
#  'ZTF18abmegax',
#  'ZTF18aabkdtr',
#  'ZTF18acrxdlh',
#  'ZTF18abcrkob',
#  'ZTF18abbmpqv',
#  'ZTF18aawstzh',
#  'ZTF18abnjtou',
#  'ZTF18abpcckj',
#  'ZTF18abcupom',
#  'ZTF18abkxkep',
#  'ZTF19aapqkqa',
#  'ZTF18abtilkg',
#  'ZTF18abkisea',
#  'ZTF17aaadyxn',
#  'ZTF18abfiqje',
#  'ZTF18abnjzns',
#  'ZTF18aaupzra',
#  'ZTF18abncvaa',
#  'ZTF18abltead',
#  'ZTF19aargvio',
#  'ZTF17aaaecdh',
#  'ZTF18abncmwm',
#  'ZTF18aabfaeq',
#  'ZTF18abssfnc',
#  'ZTF18abnophx',
#  'ZTF18abaqphq',
#  'ZTF18abadmgu',
#  'ZTF18aaudxpl',
#  'ZTF18abgvfmt',
#  'ZTF18abrfsik',
#  'ZTF18abecjgi',
#  'ZTF18abargkm',
#  'ZTF18abaqgsi',
#  'ZTF18abaqoju',
#  'ZTF17aaaedrt',
#  'ZTF18aazfebl',
#  'ZTF18ablqnjr',
#  'ZTF18acweacr',
#  'ZTF18abrzfpf',
#  'ZTF18abmpdir',
#  'ZTF18abmplda',
#  'ZTF18acwwcwr',
#  'ZTF18acpvmau',
#  'ZTF18abecmew',
#  'ZTF18abhxvcl',
#  'ZTF18abluvld',
#  'ZTF18acnadvq',
#  'ZTF18aaxltwj',
#  'ZTF18abcolsw',
#  'ZTF18abhnsfb',
#  'ZTF18abgoctg',
#  'ZTF18aaohoqw',
#  'ZTF18abdjqnw',
#  'ZTF18abdihlo',
#  'ZTF18abfyncm',
#  'ZTF18acrvwsu',
#  'ZTF18aawcczo',
#  'ZTF18acueure',
#  'ZTF18abasidp',
#  'ZTF18aabfqew',
#  'ZTF18aayoamm',
#  'ZTF18abqcofl',
#  'ZTF18abmdiux',
#  'ZTF18aazelrt',
#  'ZTF18aauemqb',
#  'ZTF18aawbmjt',
#  'ZTF18aaywfvo',
#  'ZTF18aabkhba',
#  'ZTF19aapcnux',
#  'ZTF18abijitu',
#  'ZTF18abhcmvq',
#  'ZTF18aaxpozr',
#  'ZTF18abhahqh',
#  'ZTF17aabpkau',
#  'ZTF19abmyiwq',
#  'ZTF18abechux',
#  'ZTF18aazwkrp',
#  'ZTF18abimjqd',
#  'ZTF18abjaspq',
#  'ZTF18acruxpq',
#  'ZTF18abrsprs',
#  'ZTF18abiyfdu',
#  'ZTF18ablxccd',
#  'ZTF18abjklud',
#  'ZTF18acpcyob',
#  'ZTF18abnxmuj',
#  'ZTF18abmvqxs',
#  'ZTF18aaadwfq',
#  'ZTF18aawainb',
#  'ZTF18absghyh',
#  'ZTF18abdtbln',
#  'ZTF18abnbmas',
#  'ZTF19aargtgw',
#  'ZTF18aberpzt',
#  'ZTF18abebdhm',
#  'ZTF18abdikfg',
#  'ZTF18abutgxc',
#  'ZTF18aazfamo',
#  'ZTF18abctxln',
#  'ZTF18aavefdz',
#  'ZTF18abtimwp',
#  'ZTF18abecmht',
#  'ZTF18abnedvd',
#  'ZTF18aasnciw',
#  'ZTF18aavekva',
#  'ZTF18abpcbik',
#  'ZTF18abnybqx',
#  'ZTF18aauekkw',
#  'ZTF18ababqou',
#  'ZTF18abwbeug',
#  'ZTF18ablvqxh',
#  'ZTF17aabhmem',
#  'ZTF19aakqkuz',
#  'ZTF18aaaeivo',
#  'ZTF18abqavji',
#  'ZTF18aazmkch',
#  'ZTF18acpgdut',
#  'ZTF19aasgquy',
#  'ZTF18abrwqtd',
#  'ZTF19aaxsbjg',
#  'ZTF18abgpcup',
#  'ZTF18absrtdx',
#  'ZTF19aasgtez',
#  'ZTF17aaarvdr',
#  'ZTF18aazuzni',
#  'ZTF18abdkhju',
#  'ZTF19aaxpjzv',
#  'ZTF18abpqwyv',
#  'ZTF18abhcyqe',
#  'ZTF18abjrcki',
#  'ZTF17aaaeobp',
#  'ZTF18abgwitx',
#  'ZTF18abcfwxe',
#  'ZTF17aactviq',
#  'ZTF18abqeuro',
#  'ZTF18aceidqa',
#  'ZTF18abemfnw',
#  'ZTF18aatzdnw',
#  'ZTF18abxyedf',
#  'ZTF18aavyntd',
#  'ZTF19aasgosy',
#  'ZTF18abpogbp',
#  'ZTF18abktqrw',
#  'ZTF18abfxawg',
#  'ZTF18ablvwoo',
#  'ZTF18aawbjrp',
#  'ZTF18abthvsk',
#  'ZTF18abfroez',
#  'ZTF19aargppg',
#  'ZTF18aaxvaam',
#  'ZTF17aabqwns',
#  'ZTF18aaypofq',
#  'ZTF18aaoexnp',
#  'ZTF18abpampj',
#  'ZTF18abbemat',
#  'ZTF18abimomj',
#  'ZTF18abgffmb',
#  'ZTF18abcpcvu',
#  'ZTF18abcbpkz',
#  'ZTF19aadunfm',
#  'ZTF18abcvand',
#  'ZTF19abyrccj',
#  'ZTF18acgrylo',
#  'ZTF17aaaebsy',
#  'ZTF18abrnjfi',
#  'ZTF18abajswx',
#  'ZTF18absjvbx',
#  'ZTF18abdlbih',
#  'ZTF19aaxljax',
#  'ZTF18aavniti',
#  'ZTF18abvrgsp',
#  'ZTF18abckqjk',
#  'ZTF18aazelrs',
#  'ZTF18acfxoic',
#  'ZTF18acvcoll',
#  'ZTF18ablqlnw',
#  'ZTF18aaydsfl',
#  'ZTF18aaynqik',
#  'ZTF19abpxjwj',
#  'ZTF19aayxaxc',
#  'ZTF18aazfcvl',
#  'ZTF18abtvacx',
#  'ZTF18acadbre',
#  'ZTF18abzrcus',
#  'ZTF18abdxymh',
#  'ZTF18abgtrab',
#  'ZTF18aavyquh',
#  'ZTF19aaprszh',
#  'ZTF18ablwpzg',
#  'ZTF18abifsdo',
#  'ZTF18ablxluq',
#  'ZTF18abaegdp']

# %% [markdown]
# Una vez definido el sample para cada una de las clases, se procede a obtener las curvas de luz correspondiente a estas estrellas recorriendo la data de alerts.

# %%
def light_curve(array_oid,alerts):
  df_array = []
  for chunk in alerts:
      aux_df = chunk[chunk['oid'].isin(array_oid)]
      df_array.append(aux_df)
  df = pd.concat(df_array)
  df.dropna(inplace=True)
  df.reset_index(inplace=True,drop=True)
  return df

# %%
df = light_curve(oid_sample,alerts)
df
# Out:
#                 oid               candid  fid           mjd  magpsf_corr  \
# 0      ZTF18aaxdoeg   518400060115010004    1  58272.400069    16.299545
# 1      ZTF18aaxdoeg   715119490115015007    1  58469.119491    15.210057
# 2      ZTF18abfitme   955208613315010005    2  58709.208611    15.743909
# 3      ZTF18aaxjjot   950289083115010012    2  58704.289086    14.963398
# 4      ZTF18aaxjjot  1138567223115010013    1  58892.567222    17.243220
# ...             ...                  ...  ...           ...          ...
# 94714  ZTF18aaupzra   833509510015010023    2  58587.509514    14.864432
# 94715  ZTF18aaupzra   891421891315010033    1  58645.421898    17.985100
# 94716  ZTF18abyohjt  1037299532315010003    1  58791.299537    18.066425
# 94717  ZTF18abypodv  1120204820815010006    1  58874.204826    20.365503
# 94718  ZTF18aaxdoeg   863456640115010009    1  58617.456643    16.116219
#
#        sigmapsf_corr  sigmapsf_corr_ext
# 0         100.000000           0.008553
# 1         100.000000           0.016599
# 2         100.000000           0.020520
# 3         100.000000           0.011725
# 4           0.041481           0.045674
# ...              ...                ...
# 94714     100.000000           0.030290
# 94715       0.047886           0.060525
# 94716       0.126611           0.156899
# 94717       2.358758           3.003142
# 94718       0.032723           0.051204
#
# [94719 rows x 7 columns]

# %% [markdown]
# ## 5) Extracción de características

# %% [markdown]
# A partir de las curvas de luz es que pueden extraer las características que se desean observar para cada una de las estrellas. Estas características se deben extraer de las bandas 'r' y 'g', por lo que se deben asignar estas bandas a la data anterior.

# %%
def preprocessing(df):
  df_array = []
  for oid in df['oid'].unique():
    df_aux = df[df['oid']==oid]
    min_time =  df_aux['mjd'].min()
    df_aux['mjd'] = df_aux['mjd'] - min_time
    df_array.append(df_aux)
  df = pd.concat(df_array)
  df.replace({'fid': {1: 'g', 2: 'r'}},inplace=True)
  df = df[['oid','mjd','magpsf_corr','sigmapsf_corr_ext', 'fid']]
  df.set_index('oid', inplace=True)
  df.rename(columns={'mjd': 'time', 'magpsf_corr': 'magnitude', 'sigmapsf_corr_ext': 'error', 'fid': 'band'}, inplace=True)
  return df

# %%
df_prep = preprocessing(df)
df_prep
# Out:
#  /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                     time  magnitude     error band
# oid
# ZTF18aaxdoeg    5.934896  16.299545  0.008553    g
# ZTF18aaxdoeg  202.654317  15.210057  0.016599    g
# ZTF18aaxdoeg   46.894051  16.919165  0.130291    g
# ZTF18aaxdoeg  405.874259  16.964485  0.138726    g
# ZTF18aaxdoeg  738.013102  16.717918  0.097689    g
# ...                  ...        ...       ...  ...
# ZTF19aawzasm   45.022535  15.503465  0.012745    r
# ZTF19aawzasm    7.062384  15.790150  0.013578    r
# ZTF19aawzasm   14.020752  15.755711  0.007959    r
# ZTF19aawzasm  317.083171  18.410048  0.053745    g
# ZTF19aawzasm    1.980509  15.755926  0.016561    r
#
# [94719 rows x 4 columns]

# %% [markdown]
# Una vez asignadas estas bandas, es que se puede utilizar la librería TurboFats instalada en un inicio para la extracción de las características.

# %%
def features(df):
  df_array = []
  for oid in df.index.unique():
    df_aux = df[df.index==oid]
    bands = ['r','g']
    feature_extractor = FeatureExtractorComposer(
        [
            MHPSExtractor(bands),
            PeriodExtractor(bands),
            GPDRWExtractor(bands),
            FoldedKimExtractor(bands),
            HarmonicsExtractor(bands),
            IQRExtractor(bands),
            PowerRateExtractor(bands),
            TurboFatsFeatureExtractor(bands)
        ]
    )
    features = feature_extractor.compute_features(df_aux)
    df_array.append(features)
  return pd.concat(df_array)

# %%
df_features = features(df_prep)
df_features
# Out:
#  /content/src/turbofats/turbofats/FeatureFunctionLib.py:687: RuntimeWarning:divide by zero encountered in true_divide
#  /content/src/turbofats/turbofats/FeatureFunctionLib.py:693: RuntimeWarning:invalid value encountered in double_scalars
#  /content/src/turbofats/turbofats/FeatureFunctionLib.py:437: RuntimeWarning:divide by zero encountered in true_divide
#  /content/src/turbofats/turbofats/FeatureFunctionLib.py:687: RuntimeWarning:divide by zero encountered in true_divide
#  /content/src/turbofats/turbofats/FeatureFunctionLib.py:693: RuntimeWarning:invalid value encountered in double_scalars
#  /content/src/turbofats/turbofats/FeatureFunctionLib.py:437: RuntimeWarning:divide by zero encountered in true_divide
#  /content/src/turbofats/turbofats/FeatureFunctionLib.py:690: RuntimeWarning:invalid value encountered in multiply
#  /content/src/turbofats/turbofats/FeatureFunctionLib.py:437: RuntimeWarning:invalid value encountered in true_divide
#  /content/src/turbofats/turbofats/FeatureSpace.py:57: RankWarning:Polyfit may be poorly conditioned
#               MHPS_ratio_r  MHPS_low_r  MHPS_high_r  MHPS_non_zero_r  \
# oid
# ZTF18aaxdoeg           NaN         NaN          NaN              NaN
# ZTF18abfitme    679.543152    0.422975     0.000622            103.0
# ZTF18aaxjjot    291.982910    0.609018     0.002086            110.0
# ZTF19abyrccj    822.149719    0.431830     0.000525            114.0
# ZTF19aadunfm    298.188385    0.351813     0.001180             23.0
# ...                    ...         ...          ...              ...
# ZTF19aapcnux           NaN         NaN          NaN              NaN
# ZTF18abpfgtx    218.907349    0.416913     0.001905              9.0
# ZTF19aaxljax      0.846344    0.000281     0.000332              6.0
# ZTF19aaxtyoo           NaN         NaN          NaN              NaN
# ZTF19aawzasm   1120.417603    0.769635     0.000687              4.0
#
#               MHPS_PN_flag_r  MHPS_ratio_g  MHPS_low_g  MHPS_high_g  \
# oid
# ZTF18aaxdoeg             NaN    858.060608   14.731952     0.017169
# ZTF18abfitme             0.0     17.493587    0.056117     0.003208
# ZTF18aaxjjot             0.0     74.698135    0.085363     0.001143
# ZTF19abyrccj             0.0   2520.500732    0.935664     0.000371
# ZTF19aadunfm             0.0   5486.484863    0.917905     0.000167
# ...                      ...           ...         ...          ...
# ZTF19aapcnux             NaN    237.917679    1.745530     0.007337
# ZTF18abpfgtx             0.0           NaN         NaN          NaN
# ZTF19aaxljax             0.0           NaN         NaN          NaN
# ZTF19aaxtyoo             NaN  12838.236328   11.296966     0.000880
# ZTF19aawzasm             0.0           NaN         NaN          NaN
#
#               MHPS_non_zero_g  MHPS_PN_flag_g  ...    Skew_g  SmallKurtosis_g  \
# oid                                            ...
# ZTF18aaxdoeg            210.0             0.0  ... -1.406576         1.557065
# ZTF18abfitme             94.0             1.0  ... -2.522532        14.533493
# ZTF18aaxjjot            115.0             1.0  ... -0.680564        -0.972946
# ZTF19abyrccj            149.0             0.0  ... -2.059650         5.910410
# ZTF19aadunfm              5.0             0.0  ... -0.216204        -0.661194
# ...                       ...             ...  ...       ...              ...
# ZTF19aapcnux             13.0             0.0  ...  0.044173        -1.737380
# ZTF18abpfgtx              NaN             NaN  ...       NaN              NaN
# ZTF19aaxljax              NaN             NaN  ...  0.033698        -1.832066
# ZTF19aaxtyoo              3.0             0.0  ... -0.370294        -0.706549
# ZTF19aawzasm              NaN             NaN  ...       NaN              NaN
#
#                  Std_g  StetsonK_g  Pvar_g  ExcessVar_g  SF_ML_amplitude_g  \
# oid
# ZTF18aaxdoeg  0.666209    0.624368     1.0     0.001593           6.311979
# ZTF18abfitme  0.137235    0.503983     1.0     0.000029           2.346344
# ZTF18aaxjjot  0.261611    0.945855     1.0     0.000225           0.282047
# ZTF19abyrccj  0.119814    0.638703     1.0     0.000060           0.797880
# ZTF19aadunfm  0.207553    0.951489     1.0     0.000167           0.548506
# ...                ...         ...     ...          ...                ...
# ZTF19aapcnux  1.077857    0.870273     1.0     0.005321           4.788002
# ZTF18abpfgtx       NaN         NaN     NaN          NaN                NaN
# ZTF19aaxljax  0.088178    0.934817     1.0     0.000039           0.428964
# ZTF19aaxtyoo  0.538679    0.885861     1.0     0.001077           3.198733
# ZTF19aawzasm       NaN         NaN     NaN          NaN                NaN
#
#               SF_ML_gamma_g  IAR_phi_g  LinearTrend_g
# oid
# ZTF18aaxdoeg       1.236532   0.996571      -0.000680
# ZTF18abfitme       1.339182   0.986195       0.000174
# ZTF18aaxjjot       0.598197   0.997247       0.001137
# ZTF19abyrccj       0.780156   0.985235      -0.001388
# ZTF19aadunfm       0.418724   0.982293      -0.000838
# ...                     ...        ...            ...
# ZTF19aapcnux       0.866140   0.997429       0.007150
# ZTF18abpfgtx            NaN        NaN            NaN
# ZTF19aaxljax       1.157633   0.997554       0.000578
# ZTF19aaxtyoo       0.716611   0.983527      -0.001533
# ZTF19aawzasm            NaN        NaN            NaN
#
# [600 rows x 112 columns]

# %% [markdown]
# Finalmente se obtuvieron las características de toda la clase LPV como se especificó en un inicio. Descomentando las líneas de código corrrespondientes en la sección 4) se obtienen los dataframes correspondientes a las características de cada una de las clases. Esta data se procede a guardar para poder utilizar en la segunda parte del proyecto.

# %%
#Código de ejemplo para guardar la data de las características
#df_features.to_csv('LPV_features.csv') 
#files.download('LPV_features.csv')
